# %%
import pandas as pd
from google_play_scraper import Sort, reviews

# ID paket aplikasi WhatsApp
app_id = 'com.whatsapp'

# Batas jumlah ulasan yang ingin diambil
count = 10000

# Mengambil ulasan
result, continuation_token = reviews(
    app_id,
    lang='en',  
    country='us',
    sort=Sort.NEWEST, 
    count=count
)

# %%
# Konversi ke DataFrame
df = pd.DataFrame(result)

# %%
df
# Out:
#                                   reviewId       userName  \
# 0     7849afec-6205-4e9c-a426-fd547726c497  A Google user
# 1     8f3ce03c-9722-453c-9d32-e3e794c2a448  A Google user
# 2     c278ddd5-2594-429d-b925-4021c3538b3e  A Google user
# 3     84711559-0929-4ff1-9b5f-132d0672f729  A Google user
# 4     8b3978fe-93b3-41e4-9bfa-b35658e45aed  A Google user
# ...                                    ...            ...
# 9995  dbd45b14-58af-47c6-9c54-34757bdd796e    Badal Kumar
# 9996  1ebd84c8-31b1-463a-8536-8e2b7b346b40   Rahul Sharma
# 9997  04584385-2af9-4689-9ef1-00d4be47fbf4  Tiwain Wealth
# 9998  30dc754f-d870-4a19-93c8-a5568ca386ba  Esther Joseph
# 9999  8e03477e-2534-4048-bbde-cb5790a3e993   Mubiru Jovan
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
# Memilih kolom yang diinginkan
df = df[['userName', 'score', 'content', 'at']]

# %%
# Bersihkan baris kosong
df.dropna(subset=['content', 'score'], inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9968\3945377962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['content', 'score'], inplace=True)

# %%
# Simpan ke dalam file CSV
df.to_csv('whatsapp_reviews.csv', index=False, encoding='utf-8-sig')

print(f"Berhasil menyimpan {len(df)} review ke dalam data whatsapp_reviews.csv")
# Out:
# Berhasil menyimpan 9999 review ke dalam data whatsapp_reviews.csv
